# %% [markdown]
# **SfM BATHYMETRY WORKFLOW**

# %% [markdown]
# **Getting started**
#
# To ensure working environment works properly, set to the top level of repository

# %%
cd ..
# Out:
# d:\PROGRAM

# %% [markdown]
# **Load Packages**
#
# Firstly, we need to import packages that will be use in this notebook

# %%
from sfmbathy.prep import load_las

# %% [markdown]
# **Set Input and Output Directory**
#
# Set input and output folder (Please be aware with folder name)

# %%
input_path = "D:\PROGRAM\PROGRAM_MATLAB\GUI_SFM\DATA\LAS_KELAPA_DUA.las"

# %% [markdown]
# **Start Load Data**
#
# The input for this process is the point cloud from SfM Photogrammetry in LAS format

# %%
pc,las = load_las(input_path)

print(f"Total points : {len(pc):,}")
print(f"X range      : {pc[:,0].min():.2f} → {pc[:,0].max():.2f}")
print(f"Y range      : {pc[:,1].min():.2f} → {pc[:,1].max():.2f}")
print(f"Z range      : {pc[:,2].min():.2f} → {pc[:,2].max():.2f}")

crs = las.header.parse_crs()
if crs is not None:
    print(f"CRS Name     : {crs.name}")
    print(f"EPSG Code    : {crs.to_epsg()}")
else:
    print("⚠️ No CRS found in file!")
# Out:
# Total points : 4,437,821
# X range      : 672888.44 → 674142.12
# Y range      : 9375025.00 → 9375693.00
# Z range      : -2.17 → 21.32
# CRS Name     : WGS 84 / UTM zone 48S
# EPSG Code    : 32748

# %%
from eo_tides.utils import list_models
from pyTMD.io.model import load_database
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from eo_tides.utils import list_models
#       2 from pyTMD.io.model import load_database
#
# File d:\PROGRAM\PYTHON\sfm-bathy-mapper\.venv\Lib\site-packages\eo_tides\__init__.py:29
#      26 from importlib.metadata import version
#      28 # Import commonly used functions for convenience
# ---> 29 from .eo import pixel_tides, tag_tides, tag_timeseries
#      30 from .model import ensemble_tides, model_phases, model_tides
#      31 from .stac import load_ndwi_mpc, stac_load
#
# File d:\PROGRAM\PYTHON\sfm-bathy-mapper\.venv\Lib\site-packages\eo_tides\eo.py:27
#      23     import os
#      25     from odc.geo import Shape2d
# ---> 27 from .model import model_phases, model_tides
#      28 from .utils import DatetimeLike, _standardise_time
#      31 def _resample_chunks(
# ...
